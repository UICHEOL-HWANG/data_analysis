# %%
import requests
from bs4 import BeautifulSoup as bs
import time
url ="https://www.sta1.com/shops?gndr=F&shopType=S&pg=2"

response = requests.get(url)
response.url
soup = bs(response.text,"lxml")

# %%
response.url
# Out:
# 'https://www.sta1.com/shops?gndr=F&shopType=S&pg=2'

# %%
for i in soup.select(".item"):
    print(i.select_one(".shop-name").text if i.select_one(".shop-name") is not None else "None" )
# Out:
# None
# 아뜨랑스
# 소울메이트
# 젝시믹스
# 리린
# 안나앤모드
# 안나키즈
# 스토리나인
# 핫핑
# 공구우먼
# 썸제이
# 베니토
# 메이블루
# 리틀블랙
# 안나앤블루
# 로즈베이
# 난닝구
# 하나언니
# 육육걸즈
# 메이비베이비
# 리리앤코
# 딘트
# 그레이시크
# 슬로우앤드
# 로미스토리
# 사뿐
# 데일리룩
# 코코블랙
# 젬마월드
# 피그먼트
# 홀릭홀릭
# 메이빈스
# 민스샵
# 클릭앤퍼니
# 착한구두
# 러브패리스
# 마리앙플러스
# 캔마트
# 다바걸
# 파티수
# 미아마스빈
# 츄
# 반하루
# 나인
# 조아맘
# 라이크유
# 룸페커
# 분홍코끼리
# 프롬비기닝
# 제이스타일
# 갠소
# 원로그
# 브론즈부부
# 주줌
# 아이팜므
# 프로스트제이
# 마지아룩
# 악녀일기
# 플라이모델
# 모코블링
# 에린
# 라걸
# 미뉴에트
# 라일론
# 체리코코
# 몸빼
# 더무드
# 레미떼
# 98도씨
# 고고싱
# 블랙업
# 로렌하이
# 메리어라운드
# 더카라
# 시크라인
# 스타일난다
# 스위트플러스
# 시크헤라
# 저스트원
# 비바루비
# 하비언니
# 밀크코코아
# 시크릿라벨
# 소보제화
# 45번가
# 가내스라
# 로니엘
# 퓨어다
# 어바웃썸
# 제이마인
# 트윈시스
# 11AM
# 소임
# 시부야
# 써니11
# 빌드
# 안나디바
# 시크폭스
# 핑크시슬리
# 안녕윤수야
# 오드
# 디프니
# 스타일온미
# 스컬피그
# 커먼유니크
# 비숍
# 민지콩
# 도드리
# 럭스위즈
# 마이더스비
# 디스코살롱
# 오제이럭셔리
# 지젤슈즈
# 나나살롱
# 니쁜스
# 라두나
# 업타운홀릭
# 베리유
# 코코제인
# 권조
# 나이스홍
