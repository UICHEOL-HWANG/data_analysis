# %%
import requests
from bs4 import BeautifulSoup as bs
url ="https://www.yes24.com/24/category/bestseller"
payload = dict(CategoryNumber="001",sumgb="06",PageNumber="1")

response = requests.get(url,params=payload)

soup = bs(response.content,"lxml")

# %%
data_list = []  # 데이터를 저장할 리스트 초기화

for i in soup.select("#category_layout"):
    notices = i.select("tr:nth-child(2n)")  # 공지 데이터
    books = i.select("tr:nth-child(2n+1)")  # 도서 정보 데이터

    for notice, book in zip(notices, books):
        star_on_count = 0
        star_off_count = 0

        book_data = {
            "제목": book.select_one(".goodsTxtInfo").select_one("p").text[0:5],
            "작가": book.select_one(".goodsTxtInfo p").select_one("a").text,
            "출판사": book.select_one(".aupu").text.split("|")[0].strip(),
            "출간일": book.select_one(".aupu").text.split("|")[1].strip(),
            "별점": "",
            "편집구성 별점": ""
        }

        # 도서 정보의 별점 데이터 처리
        if book.select_one(".review") is not None:
            for rate in book.select_one(".review").select("img")[0:5]:
                src = rate["src"]
                if "StarOn.gif" in src:
                    star_on_count += 1
                elif "StarOff.gif" in src:
                    star_off_count += 1
            total_star_count = star_on_count + star_off_count
            if total_star_count > 0:
                rating = (star_on_count / total_star_count) * 5
            else:
                rating = 0
            book_data["별점"] = rating

        # 편집구성 별점 데이터 처리 (이하 동일)

        # 공지 데이터 처리
        notice_data = {
            "공지": notice.select_one(".read").text.strip(),
        }

        if notice_data:
            data_list.append({**notice_data, **book_data})
        else:
            data_list.append(book_data)

# 데이터 리스트 출력 (테스트용)
for data in data_list:
    print(data)
# Out:
# {'공지': '첫 발표 이후 43년, 마음에 품어왔던 소설을 마침내 완성하다. 하루키적 상상력의 모든 것이 담긴 결정적 세계!  “이 작품에는 무언가 나에게 매우 중요한 요소가 포함되어 있다고, 처음부터 그렇게 느껴왔다.” _무라카미 하루키   무라카미 하루키의 신작 장편소설 『도시와 그 불확실한 벽』의 한국어판이 9월 6...', '제목': '[도서] ', '작가': '도시와 그 불확실한 벽', '출판사': '무라카미 하루키 저/홍은주 역', '출간일': '문학동네', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '‘미래의 나’를 적용하는 과학 분야 세계 최고의 전문가, 자기계발 분야 파워블로거이자 베스트셀러 작가의 신작 세계적인 동기부여 전문가, 토니 로빈스 강력 추천!  현재와 미래를 더 가치 있게 바꾸고 싶다면, ‘미래의 나’와 연결하라!  살 날이 얼마 남지 않은 ‘미래의 내’가 현재로 시간 여행을 왔다고 상...', '제목': '[도서] ', '작가': '퓨처 셀프', '출판사': '벤저민 하디 저/최은아 역', '출간일': '상상스퀘어', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '“등에 화살이 꽂힌 채 길 없는 길을 묵묵히 걸어가겠다.” 법대 교수, 법무부장관에서 자연인으로 돌아온 조국의 첫 에세이  2023년 6월 12일 법학자 조국은 서울대로부터 교수직을 파면당했다. 이 책은 법대 교수 조국이 법을 공부한 이유와 자신이 생각하는 공부의 참된 의미에 대해 기록한 책 『왜 나는 법을 공부하...', '제목': '[도서] ', '작가': '디케의 눈물', '출판사': '조국 저', '출간일': '다산북스', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '유튜브 261만 구독 돌파! 인기 크리에이터 흔한남매 웃음에 겨워 춤이 절로 나오는 흔한남매의 신나는 일상!  ‘흔한남매’는 유튜브 구독자 수가 261만 명, 누적 조회 수가 32억 회를 넘어서는 인기 크리에이터로, 흔한컴퍼니에 소속되어 있습니다. 상황극·콩트 등을 통해 어린이들에게 큰 사랑을 받고 있으며, 주로 남...', '제목': '[도서] ', '작가': '흔한남매 14', '출판사': '흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수', '출간일': '미래엔아이세움', '별점': '', '편집구성 별점': ''}
# {'공지': '“미래는 꿈꾸는 것이 아니라 만드는 것, 그가 상상하면 모두 현실이 된다!”   천재인가 몽상가인가, 영웅인가 사기꾼인가?  수많은 논란 속에서도 1%의 가능성에 모든 걸 걸며  인류의 미래를 바꾸는 이 시대 최고의 혁신가, 일론 머스크의 모든 것!  스티브 잡스의 유일한 공식 전기를 쓴 저자 월터 아이작슨이 ...', '제목': '[도서] ', '작가': '일론 머스크', '출판사': '월터 아이작슨 저/안진환 역', '출간일': '21세기북스', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '재야의 명저 『세이노의 가르침』 2023년판 정식 출간! 순자산 천억 원대 자산가, 세이노의 ‘요즘 생각’을 만나다  2000년부터 발표된 그의 주옥같은 글들. 독자들이 자발적으로 만든 제본서는 물론, 전자책과 앱까지 나왔던 『세이노의 가르침』이 드디어 서점에서 독자들을 마주한다. 여러 판본을 모으고 저자의 확...', '제목': '[도서] ', '작가': '세이노의 가르침', '출판사': '세이노(SayNo) 저', '출간일': '데이원', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '네이버 블로그 경제·주식 분야 1위  SERICEO 비즈니스 북클럽 선정도서  국내 최고의 자본시장 분석가 메르의 투자 인사이트   국내 최고의 자본시장 분석가이자, 경제·주식 분야 파워 인플루언서로 타의 추종을 불허하는 독보적인 시각을 제시하는 메르의 모든 투자 노하우를 담은 책이다. 2020년 이후 주식시장에 뛰...', '제목': '[도서] ', '작가': '1%를 읽는 힘', '출판사': '메르 저', '출간일': '토네이도', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '아마존, 월 스트리트 저널 올해의 책 애덤 그랜트·수전 케인·힐러리 클린턴 추천, 2023년 최고의 화제작  “우리는 어떻게 ‘나도 모르는 새’ 집중력을 도둑맞고 있을까” 3만 마일의 비행, 250명 전문가와의 인터뷰 뉴욕타임스 베스트셀러 작가의 전방위적인 탐사가 시작된다  전 세계 모든 곳에서, 집중하는 우리...', '제목': '[도서] ', '작가': '도둑맞은 집중력', '출판사': '요한 하리 저/김하현 역', '출간일': '어크로스', '별점': 4.0, '편집구성 별점': ''}
# {'공지': 'tvN [알쓸별잡] 김상욱 교수 강력 추천! 《폴리티켄》 《데일리 뵈르센》 등 덴마크 다수 일간지 강력 추천!  “4시간만 일해도 되는 사회를 만들어놓고 왜 8시간이나 일하는가?”  일하지 않는 ‘가짜 노동’의 시대  우리가 더 많은 일을 하는 진짜 이유  『가짜 노동: 스스로 만드는 번아웃의 세계』는 우리 사회...', '제목': '[도서] ', '작가': '가짜 노동', '출판사': '데니스 뇌르마르크,아네르스 포그 옌센 저/이수영 역', '출간일': '자음과모음', '별점': 4.0, '편집구성 별점': ''}
# {'공지': "에그 헤드에 상륙한 밀짚모자 일당. 그곳에는 Dr. 베가펑크의 연구소가 있고, 갖가지 미지의 기술들에 루피의 모험심이 고양된다!! 하지만, 베가펑크 밀살을 위해 CPO가 습격을?! '원피스'를 둘러싼 해양 모험 로망!!", '제목': '[만화] ', '작가': '원피스 ONE PIECE 106', '출판사': '오다 에이이치로 글그림', '출간일': '대원', '별점': '', '편집구성 별점': ''}
# {'공지': '청룡을 타고 비상하는 2024를 기원하며!', '제목': '[도서] ', '작가': '트렌드 코리아 2024 ', '출판사': '김난도,전미영,최지혜,이수진,권정윤,한다혜,이준영,이향은,이혜원,추예린,전다현 공저', '출간일': '미래의창', '별점': '', '편집구성 별점': ''}
# {'공지': '70만 구독, 최고의 교육채널 「아들TV」  최민준 소장의 기질 맞춤 아들 육아법  영유아기부터 사춘기가 시작된 아들 부모 모두를 위한 필독서   “적절한 수용과 단호함으로 아들을 바르게 키우는 법”  아들의 한 번 말해서 듣지 않는 행동, 게임 중독, 거침없는 표현 등으로 아들맘은 무너질 때가 많다. 아이에게 ...', '제목': '[도서] ', '작가': '최민준의 아들코칭 백과', '출판사': '최민준 저', '출간일': '위즈덤하우스', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '국내외 총 판매량 300만 부의 밀리언셀러  한국 판타지의 모범이자 현재진행형인 전설  아름다운 세계관과 개성 넘치는 캐릭터, 유려한 문체와 깊이 있는 감성으로 한국 판타지를 이끌어온 전민희 작가의 대표작 『룬의 아이들』 신작이 엘릭시르에서 출간된다. ‘룬의 아이들’ 시리즈는 국내 판매량 총 160만 부를 넘...', '제목': '[도서] ', '작가': '룬의 아이들 - 블러디드 6', '출판사': '전민희 저', '출간일': '엘릭시르', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '한층 더 강력한 치트키, 독해진 팩트 폭격! 50주 연속 베스트셀러·40만 독자의 삶을 바꾼  『역행자』가 확장판으로 돌아왔다  “절대로 읽지 마라!  죽을 때까지 순리자로 살고 싶다면!”   95퍼센트의 인간은 타고난 유전자와 본성의 꼭두각시로 살아간다. 이들은 평생 돈, 시간, 운명에게 속박되어, 평범함을 벗...', '제목': '[도서] ', '작가': '역행자 확장판', '출판사': '자청 저', '출간일': '웅진지식하우스', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '*** 한국사 강의 압도적 1위! *** *** 누적 수강생 600만 명 ***  대한민국 대표 역사 강사 최태성의 5천 년 역사가 단숨에 이해되는 핵심 한국사  ‘외워야 할 것 많고 어려운 한국사, 쉽고 빠르고 재미있게 핵심 내용만 알 수 없을까?’ 많은 사람이 역사 공부에 앞서 품는 이 질문에 답하기 위해 대한민국 대표 역...', '제목': '[도서] ', '작가': '최소한의 한국사', '출판사': '최태성 저', '출간일': '프런트페이지', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '과학 공부로 길어 올린 생명과 우주에 관한 진실, 인간과 사회를 이해하는 방법 “내 삶을 어떤 의미로 채울 것인가?”   지금 여기, 지식과 교양의 새로운 패러다임  과학의 사유와 인문학의 성찰이 함께하는 지적 여정   “문과도 과학적으로 생각할 수 있다!”    『문과 남자의 과학 공부』는 역사 · 정치 · 경...', '제목': '[도서] ', '작가': '문과 남자의 과학 공부', '출판사': '유시민 저', '출간일': '돌베개', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '네이버 발행 즉시 2만 뷰 돌파, 화제의 《아홉 살 신문》이 한 권의 책으로 돌아왔다!  똑똑해지려면 반드시 알아야 하는 100가지 최신 핵심 뉴스! 아홉 살에 시작해 열세 살에 완성하는 ‘비문학 독해 근력’!  초등학생을 자녀로 둔 학부모들 사이에서 ‘비문학 독서’에 대한 관심이 날로 높아지고 있다. 대학수학...', '제목': '[도서] ', '작가': '아홉 살에 시작하는 똑똑한 초등신문', '출판사': '신효원 저', '출간일': '책장속북스', '별점': 4.0, '편집구성 별점': ''}
# {'공지': '베스트셀러 『아기 판다 푸바오』의 후속작 장난꾸러기 푸바오의 행복한 일상을 담은 포토 에세이    2020년 7월 20일에 태어난 국내 탄생 1호 아기 판다 푸바오가 벌써 세 살이 되었습니다. 어느덧 완연한 어른 판다가 된 푸바오는 아기 때에 비해 활동량이 월등히 늘었고, 감정 표현도 훨씬 더 풍부해졌습니다. 무엇보...', '제목': '[도서] ', '작가': '푸바오, 매일매일 행복해', '출판사': '에버랜드 동물원 글그림/강철원 글/류정훈 사진', '출간일': '시공주니어', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '“제 이름은 조민입니다.”  사회적 논란의 중심에서 누구의 딸이 아닌, ‘조민’ 그 자체로 살아가기 위해 발을 내딛다   저자 조민은 짧은 의사 생활을 마감하고 새내기 크리에이터의 삶을 사는 청년이다. 유튜브 채널 쪼민(minchobae)으로 채널을 개설한 지 5개월 만에 30만 구독자를 돌파했으며, 인스타그램 팔로...', '제목': '[도서] ', '작가': '오늘도 나아가는 중입니다', '출판사': '조민 저', '출간일': '참새책방', '별점': 5.0, '편집구성 별점': ''}
# {'공지': '“금수저도, 상식 밖의 천재도 아닌데  평범함의 범주 안에서 잘 먹고 잘사는 사람들, 나는 이들을 ‘슈퍼노멀’이라고 부른다. 이 책은 슈퍼노멀로 거듭나는 법에 관한 이야기다.”   일평생 돈 걱정 하면서 살고 싶은 사람이 어디 있을까? 하지만 다들 부자의 삶을 꿈꾸면서도 체념해버린다. 금수저도, 천재도 아니...', '제목': '[도서] ', '작가': '슈퍼노멀', '출판사': '주언규 저', '출간일': '웅진지식하우스', '별점': 4.0, '편집구성 별점': ''}

# %%
data_list
# Out:
# [{'공지': '첫 발표 이후 43년, 마음에 품어왔던 소설을 마침내 완성하다. 하루키적 상상력의 모든 것이 담긴 결정적 세계!  “이 작품에는 무언가 나에게 매우 중요한 요소가 포함되어 있다고, 처음부터 그렇게 느껴왔다.” _무라카미 하루키   무라카미 하루키의 신작 장편소설 『도시와 그 불확실한 벽』의 한국어판이 9월 6...',
#   '제목': '[도서] ',
#   '작가': '도시와 그 불확실한 벽',
#   '출판사': '무라카미 하루키 저/홍은주 역',
#   '출간일': '문학동네',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '‘미래의 나’를 적용하는 과학 분야 세계 최고의 전문가, 자기계발 분야 파워블로거이자 베스트셀러 작가의 신작 세계적인 동기부여 전문가, 토니 로빈스 강력 추천!  현재와 미래를 더 가치 있게 바꾸고 싶다면, ‘미래의 나’와 연결하라!  살 날이 얼마 남지 않은 ‘미래의 내’가 현재로 시간 여행을 왔다고 상...',
#   '제목': '[도서] ',
#   '작가': '퓨처 셀프',
#   '출판사': '벤저민 하디 저/최은아 역',
#   '출간일': '상상스퀘어',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '“등에 화살이 꽂힌 채 길 없는 길을 묵묵히 걸어가겠다.” 법대 교수, 법무부장관에서 자연인으로 돌아온 조국의 첫 에세이  2023년 6월 12일 법학자 조국은 서울대로부터 교수직을 파면당했다. 이 책은 법대 교수 조국이 법을 공부한 이유와 자신이 생각하는 공부의 참된 의미에 대해 기록한 책 『왜 나는 법을 공부하...',
#   '제목': '[도서] ',
#   '작가': '디케의 눈물',
#   '출판사': '조국 저',
#   '출간일': '다산북스',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '유튜브 261만 구독 돌파! 인기 크리에이터 흔한남매 웃음에 겨워 춤이 절로 나오는 흔한남매의 신나는 일상!  ‘흔한남매’는 유튜브 구독자 수가 261만 명, 누적 조회 수가 32억 회를 넘어서는 인기 크리에이터로, 흔한컴퍼니에 소속되어 있습니다. 상황극·콩트 등을 통해 어린이들에게 큰 사랑을 받고 있으며, 주로 남...',
#   '제목': '[도서] ',
#   '작가': '흔한남매 14',
#   '출판사': '흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수',
#   '출간일': '미래엔아이세움',
#   '별점': '',
#   '편집구성 별점': ''},
#  {'공지': '“미래는 꿈꾸는 것이 아니라 만드는 것, 그가 상상하면 모두 현실이 된다!”   천재인가 몽상가인가, 영웅인가 사기꾼인가?  수많은 논란 속에서도 1%의 가능성에 모든 걸 걸며  인류의 미래를 바꾸는 이 시대 최고의 혁신가, 일론 머스크의 모든 것!  스티브 잡스의 유일한 공식 전기를 쓴 저자 월터 아이작슨이 ...',
#   '제목': '[도서] ',
#   '작가': '일론 머스크',
#   '출판사': '월터 아이작슨 저/안진환 역',
#   '출간일': '21세기북스',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '재야의 명저 『세이노의 가르침』 2023년판 정식 출간! 순자산 천억 원대 자산가, 세이노의 ‘요즘 생각’을 만나다  2000년부터 발표된 그의 주옥같은 글들. 독자들이 자발적으로 만든 제본서는 물론, 전자책과 앱까지 나왔던 『세이노의 가르침』이 드디어 서점에서 독자들을 마주한다. 여러 판본을 모으고 저자의 확...',
#   '제목': '[도서] ',
#   '작가': '세이노의 가르침',
#   '출판사': '세이노(SayNo) 저',
#   '출간일': '데이원',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '네이버 블로그 경제·주식 분야 1위  SERICEO 비즈니스 북클럽 선정도서  국내 최고의 자본시장 분석가 메르의 투자 인사이트   국내 최고의 자본시장 분석가이자, 경제·주식 분야 파워 인플루언서로 타의 추종을 불허하는 독보적인 시각을 제시하는 메르의 모든 투자 노하우를 담은 책이다. 2020년 이후 주식시장에 뛰...',
#   '제목': '[도서] ',
#   '작가': '1%를 읽는 힘',
#   '출판사': '메르 저',
#   '출간일': '토네이도',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '아마존, 월 스트리트 저널 올해의 책 애덤 그랜트·수전 케인·힐러리 클린턴 추천, 2023년 최고의 화제작  “우리는 어떻게 ‘나도 모르는 새’ 집중력을 도둑맞고 있을까” 3만 마일의 비행, 250명 전문가와의 인터뷰 뉴욕타임스 베스트셀러 작가의 전방위적인 탐사가 시작된다  전 세계 모든 곳에서, 집중하는 우리...',
#   '제목': '[도서] ',
#   '작가': '도둑맞은 집중력',
#   '출판사': '요한 하리 저/김하현 역',
#   '출간일': '어크로스',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': 'tvN [알쓸별잡] 김상욱 교수 강력 추천! 《폴리티켄》 《데일리 뵈르센》 등 덴마크 다수 일간지 강력 추천!  “4시간만 일해도 되는 사회를 만들어놓고 왜 8시간이나 일하는가?”  일하지 않는 ‘가짜 노동’의 시대  우리가 더 많은 일을 하는 진짜 이유  『가짜 노동: 스스로 만드는 번아웃의 세계』는 우리 사회...',
#   '제목': '[도서] ',
#   '작가': '가짜 노동',
#   '출판사': '데니스 뇌르마르크,아네르스 포그 옌센 저/이수영 역',
#   '출간일': '자음과모음',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': "에그 헤드에 상륙한 밀짚모자 일당. 그곳에는 Dr. 베가펑크의 연구소가 있고, 갖가지 미지의 기술들에 루피의 모험심이 고양된다!! 하지만, 베가펑크 밀살을 위해 CPO가 습격을?! '원피스'를 둘러싼 해양 모험 로망!!",
#   '제목': '[만화] ',
#   '작가': '원피스 ONE PIECE 106',
#   '출판사': '오다 에이이치로 글그림',
#   '출간일': '대원',
#   '별점': '',
#   '편집구성 별점': ''},
#  {'공지': '청룡을 타고 비상하는 2024를 기원하며!',
#   '제목': '[도서] ',
#   '작가': '트렌드 코리아 2024 ',
#   '출판사': '김난도,전미영,최지혜,이수진,권정윤,한다혜,이준영,이향은,이혜원,추예린,전다현 공저',
#   '출간일': '미래의창',
#   '별점': '',
#   '편집구성 별점': ''},
#  {'공지': '70만 구독, 최고의 교육채널 「아들TV」  최민준 소장의 기질 맞춤 아들 육아법  영유아기부터 사춘기가 시작된 아들 부모 모두를 위한 필독서   “적절한 수용과 단호함으로 아들을 바르게 키우는 법”  아들의 한 번 말해서 듣지 않는 행동, 게임 중독, 거침없는 표현 등으로 아들맘은 무너질 때가 많다. 아이에게 ...',
#   '제목': '[도서] ',
#   '작가': '최민준의 아들코칭 백과',
#   '출판사': '최민준 저',
#   '출간일': '위즈덤하우스',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '국내외 총 판매량 300만 부의 밀리언셀러  한국 판타지의 모범이자 현재진행형인 전설  아름다운 세계관과 개성 넘치는 캐릭터, 유려한 문체와 깊이 있는 감성으로 한국 판타지를 이끌어온 전민희 작가의 대표작 『룬의 아이들』 신작이 엘릭시르에서 출간된다. ‘룬의 아이들’ 시리즈는 국내 판매량 총 160만 부를 넘...',
#   '제목': '[도서] ',
#   '작가': '룬의 아이들 - 블러디드 6',
#   '출판사': '전민희 저',
#   '출간일': '엘릭시르',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '한층 더 강력한 치트키, 독해진 팩트 폭격! 50주 연속 베스트셀러·40만 독자의 삶을 바꾼  『역행자』가 확장판으로 돌아왔다  “절대로 읽지 마라!  죽을 때까지 순리자로 살고 싶다면!”   95퍼센트의 인간은 타고난 유전자와 본성의 꼭두각시로 살아간다. 이들은 평생 돈, 시간, 운명에게 속박되어, 평범함을 벗...',
#   '제목': '[도서] ',
#   '작가': '역행자 확장판',
#   '출판사': '자청 저',
#   '출간일': '웅진지식하우스',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '*** 한국사 강의 압도적 1위! *** *** 누적 수강생 600만 명 ***  대한민국 대표 역사 강사 최태성의 5천 년 역사가 단숨에 이해되는 핵심 한국사  ‘외워야 할 것 많고 어려운 한국사, 쉽고 빠르고 재미있게 핵심 내용만 알 수 없을까?’ 많은 사람이 역사 공부에 앞서 품는 이 질문에 답하기 위해 대한민국 대표 역...',
#   '제목': '[도서] ',
#   '작가': '최소한의 한국사',
#   '출판사': '최태성 저',
#   '출간일': '프런트페이지',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '과학 공부로 길어 올린 생명과 우주에 관한 진실, 인간과 사회를 이해하는 방법 “내 삶을 어떤 의미로 채울 것인가?”   지금 여기, 지식과 교양의 새로운 패러다임  과학의 사유와 인문학의 성찰이 함께하는 지적 여정   “문과도 과학적으로 생각할 수 있다!”    『문과 남자의 과학 공부』는 역사 · 정치 · 경...',
#   '제목': '[도서] ',
#   '작가': '문과 남자의 과학 공부',
#   '출판사': '유시민 저',
#   '출간일': '돌베개',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '네이버 발행 즉시 2만 뷰 돌파, 화제의 《아홉 살 신문》이 한 권의 책으로 돌아왔다!  똑똑해지려면 반드시 알아야 하는 100가지 최신 핵심 뉴스! 아홉 살에 시작해 열세 살에 완성하는 ‘비문학 독해 근력’!  초등학생을 자녀로 둔 학부모들 사이에서 ‘비문학 독서’에 대한 관심이 날로 높아지고 있다. 대학수학...',
#   '제목': '[도서] ',
#   '작가': '아홉 살에 시작하는 똑똑한 초등신문',
#   '출판사': '신효원 저',
#   '출간일': '책장속북스',
#   '별점': 4.0,
#   '편집구성 별점': ''},
#  {'공지': '베스트셀러 『아기 판다 푸바오』의 후속작 장난꾸러기 푸바오의 행복한 일상을 담은 포토 에세이    2020년 7월 20일에 태어난 국내 탄생 1호 아기 판다 푸바오가 벌써 세 살이 되었습니다. 어느덧 완연한 어른 판다가 된 푸바오는 아기 때에 비해 활동량이 월등히 늘었고, 감정 표현도 훨씬 더 풍부해졌습니다. 무엇보...',
#   '제목': '[도서] ',
#   '작가': '푸바오, 매일매일 행복해',
#   '출판사': '에버랜드 동물원 글그림/강철원 글/류정훈 사진',
#   '출간일': '시공주니어',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '“제 이름은 조민입니다.”  사회적 논란의 중심에서 누구의 딸이 아닌, ‘조민’ 그 자체로 살아가기 위해 발을 내딛다   저자 조민은 짧은 의사 생활을 마감하고 새내기 크리에이터의 삶을 사는 청년이다. 유튜브 채널 쪼민(minchobae)으로 채널을 개설한 지 5개월 만에 30만 구독자를 돌파했으며, 인스타그램 팔로...',
#   '제목': '[도서] ',
#   '작가': '오늘도 나아가는 중입니다',
#   '출판사': '조민 저',
#   '출간일': '참새책방',
#   '별점': 5.0,
#   '편집구성 별점': ''},
#  {'공지': '“금수저도, 상식 밖의 천재도 아닌데  평범함의 범주 안에서 잘 먹고 잘사는 사람들, 나는 이들을 ‘슈퍼노멀’이라고 부른다. 이 책은 슈퍼노멀로 거듭나는 법에 관한 이야기다.”   일평생 돈 걱정 하면서 살고 싶은 사람이 어디 있을까? 하지만 다들 부자의 삶을 꿈꾸면서도 체념해버린다. 금수저도, 천재도 아니...',
#   '제목': '[도서] ',
#   '작가': '슈퍼노멀',
#   '출판사': '주언규 저',
#   '출간일': '웅진지식하우스',
#   '별점': 4.0,
#   '편집구성 별점': ''}]

# %%
import pandas as pd 

df = pd.DataFrame(data_list)
df
# Out:
#                                                    공지     제목  \
# 0   첫 발표 이후 43년, 마음에 품어왔던 소설을 마침내 완성하다. 하루키적 상상력의 ...  [도서]
# 1   ‘미래의 나’를 적용하는 과학 분야 세계 최고의 전문가, 자기계발 분야 파워블로거이...  [도서]
# 2   “등에 화살이 꽂힌 채 길 없는 길을 묵묵히 걸어가겠다.” 법대 교수, 법무부장관에...  [도서]
# 3   유튜브 261만 구독 돌파! 인기 크리에이터 흔한남매 웃음에 겨워 춤이 절로 나오는...  [도서]
# 4   “미래는 꿈꾸는 것이 아니라 만드는 것, 그가 상상하면 모두 현실이 된다!”   천...  [도서]
# 5   재야의 명저 『세이노의 가르침』 2023년판 정식 출간! 순자산 천억 원대 자산가,...  [도서]
# 6   네이버 블로그 경제·주식 분야 1위  SERICEO 비즈니스 북클럽 선정도서  국내...  [도서]
# 7   아마존, 월 스트리트 저널 올해의 책 애덤 그랜트·수전 케인·힐러리 클린턴 추천, ...  [도서]
# 8   tvN [알쓸별잡] 김상욱 교수 강력 추천! 《폴리티켄》 《데일리 뵈르센》 등 덴마...  [도서]
# 9   에그 헤드에 상륙한 밀짚모자 일당. 그곳에는 Dr. 베가펑크의 연구소가 있고, 갖가...  [만화]
# 10                            청룡을 타고 비상하는 2024를 기원하며!  [도서]
# 11  70만 구독, 최고의 교육채널 「아들TV」  최민준 소장의 기질 맞춤 아들 육아법 ...  [도서]
# 12  국내외 총 판매량 300만 부의 밀리언셀러  한국 판타지의 모범이자 현재진행형인 전...  [도서]
# 13  한층 더 강력한 치트키, 독해진 팩트 폭격! 50주 연속 베스트셀러·40만 독자의 ...  [도서]
# 14  *** 한국사 강의 압도적 1위! *** *** 누적 수강생 600만 명 ***  ...  [도서]
# 15  과학 공부로 길어 올린 생명과 우주에 관한 진실, 인간과 사회를 이해하는 방법 “내...  [도서]
# 16  네이버 발행 즉시 2만 뷰 돌파, 화제의 《아홉 살 신문》이 한 권의 책으로 돌아왔...  [도서]
# 17  베스트셀러 『아기 판다 푸바오』의 후속작 장난꾸러기 푸바오의 행복한 일상을 담은 포...  [도서]
# 18  “제 이름은 조민입니다.”  사회적 논란의 중심에서 누구의 딸이 아닌, ‘조민’ 그...  [도서]
# 19  “금수저도, 상식 밖의 천재도 아닌데  평범함의 범주 안에서 잘 먹고 잘사는 사람들...  [도서]
#
#                      작가                                             출판사  \
# 0          도시와 그 불확실한 벽                                무라카미 하루키 저/홍은주 역
# 1                 퓨처 셀프                                  벤저민 하디 저/최은아 역
# 2                디케의 눈물                                            조국 저
# 3               흔한남매 14                   흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수
# 4                일론 머스크                                 월터 아이작슨 저/안진환 역
# 5              세이노의 가르침                                    세이노(SayNo) 저
# 6              1%를 읽는 힘                                            메르 저
# 7              도둑맞은 집중력                                   요한 하리 저/김하현 역
# 8                 가짜 노동                    데니스 뇌르마르크,아네르스 포그 옌센 저/이수영 역
# 9     원피스 ONE PIECE 106                                    오다 에이이치로 글그림
# 10        트렌드 코리아 2024   김난도,전미영,최지혜,이수진,권정윤,한다혜,이준영,이향은,이혜원,추예린,전다현 공저
# 11         최민준의 아들코칭 백과                                           최민준 저
# 12      룬의 아이들 - 블러디드 6                                           전민희 저
# 13              역행자 확장판                                            자청 저
# 14             최소한의 한국사                                           최태성 저
# 15         문과 남자의 과학 공부                                           유시민 저
# 16  아홉 살에 시작하는 똑똑한 초등신문                                           신효원 저
# 17        푸바오, 매일매일 행복해                       에버랜드 동물원 글그림/강철원 글/류정훈 사진
# 18        오늘도 나아가는 중입니다                                            조민 저
# 19                 슈퍼노멀                                           주언규 저
#
#         출간일   별점 편집구성 별점
# 0      문학동네  4.0
# 1     상상스퀘어  5.0
# 2      다산북스  4.0
# 3   미래엔아이세움
# 4    21세기북스  5.0
# 5       데이원  4.0
# 6      토네이도  4.0
# 7      어크로스  4.0
# 8     자음과모음  4.0
# 9        대원
# 10     미래의창
# 11   위즈덤하우스  5.0
# 12     엘릭시르  5.0
# 13  웅진지식하우스  4.0
# 14   프런트페이지  4.0
# 15      돌베개  4.0
# 16    책장속북스  4.0
# 17    시공주니어  5.0
# 18     참새책방  5.0
# 19  웅진지식하우스  4.0
